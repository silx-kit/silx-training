# %%
# %gui qt

# %% [markdown]
# # simple plot of a 2D image
#
# - using Plot2D

# %% [markdown]
# ## load data from data/lena.hdf5

# %%
# input using .hdf5
import h5py
import numpy
dataPath='../data/ascent.h5'
f=h5py.File(dataPath)
from silx.io.utils import h5ls
h5ls(dataPath)
# Out:
# '<HDF5 dataset "data": shape (512, 512), type "<i8">\n'

# %%
image=numpy.array(f['data'], dtype='float32')

# %% [markdown]
# ## plot the image
# ![ascent image](../img/plot_ascent.png)

# %%
from silx.gui.plot import Plot2D
plotImage=Plot2D()
plotImage.addImage(image, origin=(0, 0), legend='sino') 
plotImage.show()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-6-167a9bd6760e> in <module>()
#       1 from silx.gui.plot import Plot2D
# ----> 2 plotImage=Plot2D()
#       3 plotImage.addImage(image, origin=(0, 0), legend='sino')
#       4 plotImage.show()
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     466                                      copy=True, save=True, print_=True,
#     467                                      control=False, position=posInfo,
# --> 468                                      roi=False, mask=True)
#     469         if parent is None:
#     470             self.setWindowTitle('Plot2D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
# ...
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     196         self.fitAction.setVisible(fit)
#     197
# --> 198         self.pixIntensitiesHisto = self.group.addAction(PixelIntensitiesHistoAction(self))
#     199         self.pixIntensitiesHisto.setVisible(pixelsIntensities)
#     200
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, plot, parent)
#     516                             triggered=self.computeIntensityDistribution,
#     517                             parent=parent)
# --> 518         self.plotHistogram=Plot1D()
#     519
#     520     def computeIntensityDistribution(self):
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent)
#     437                                      copy=True, save=True, print_=True,
#     438                                      control=True, position=True,
# --> 439                                      roi=True, mask=False, fit=True)
#     440         if parent is None:
#     441             self.setWindowTitle('Plot1D')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWindow.py in __init__(self, parent, backend, resetzoom, autoScale, logScale, grid, curveStyle, colormap, aspectRatio, yInverted, copy, save, print_, control, position, roi, mask, fit, pixelsIntensities)
#     121                  roi=True, mask=True, fit=False,
#     122                  pixelsIntensities=True):
# --> 123         super(PlotWindow, self).__init__(parent=parent, backend=backend)
#     124         if parent is None:
#     125             self.setWindowTitle('PlotWindow')
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/PlotWidget.py in __init__(self, parent, backend, legends, callback, **kw)
#     138         self._panWithArrowKeys = True
#     139
# --> 140         qt.QMainWindow.__init__(self, parent)
#     141         if parent is not None:
#     142             # behave as a widget
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/Plot.py in __init__(self, parent, backend)
#     283             else:
#     284                 raise ValueError("Backend not supported %s" % backend)
# --> 285             self._backend = backendClass(self, parent)
#     286
#     287         else:
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/BackendMatplotlib.py in __init__(self, plot, parent)
#     873         self._insideResizeEventMethod = False
#     874
# --> 875         BackendMatplotlib.__init__(self, plot, parent)
#     876         FigureCanvasQTAgg.__init__(self, self.fig)
#     877         self.setParent(parent)
#
# /users/payno/.local/lib/python3.5/site-packages/silx-0.4.0a0-py3.5-linux-x86_64.egg/silx/gui/plot/BackendMatplotlib.py in __init__(self, plot, parent)
#      84
#      85         self.ax = self.fig.add_axes([.15, .15, .75, .75], label="left")
# ---> 86         self.ax2 = self.ax.twinx()
#      87         self.ax2.set_label("right")
#      88
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in twinx(self)
#    3711             events are only called for the artists in the top-most axes.
#    3712         """
# -> 3713         ax2 = self._make_twin_axes(sharex=self)
#    3714         ax2.yaxis.tick_right()
#    3715         ax2.yaxis.set_label_position('right')
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in _make_twin_axes(self, *kl, **kwargs)
#    3693         make a twinx axes of self. This is used for twinx and twiny.
#    3694         """
# -> 3695         ax2 = self.figure.add_axes(self.get_position(True), *kl, **kwargs)
#    3696         return ax2
#    3697
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/figure.py in add_axes(self, *args, **kwargs)
#     913
#     914             # create the new axes using the axes class given
# --> 915             a = projection_class(self, rect, **kwargs)
#     916
#     917         self._axstack.add(key, a)
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     513         self._hold = rcParams['axes.hold']
#     514         self._connected = {}  # a dict from events to (id, func)
# --> 515         self.cla()
#     516         # funcs used to format x and y - fall back on major formatters
#     517         self.fmt_xdata = None
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in cla(self)
#     914         self.yaxis.cla()
#     915         for name, spine in six.iteritems(self.spines):
# --> 916             spine.cla()
#     917
#     918         self.ignore_existing_data_limits = True
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/spines.py in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in cla(self)
#     742         self._set_artist_props(self.label)
#     743
# --> 744         self.reset_ticks()
#     745
#     746         self.converter = None
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in reset_ticks(self)
#     756         cbook.popall(self.minorTicks)
#     757
# --> 758         self.majorTicks.extend([self._get_tick(major=True)])
#     759         self.minorTicks.extend([self._get_tick(major=False)])
#     760         self._lastNumMajorTicks = 1
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1675         else:
#    1676             tick_kw = self._minor_tick_kw
# -> 1677         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1678
#    1679     def _get_label(self):
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     416                           zorder=self._zorder)
#     417
# --> 418         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#     419         self._set_artist_props(l)
#     420         return l
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in get_xaxis_transform(self, which)
#     646         elif which == 'tick2':
#     647             # for cartesian projection, this is top spine
# --> 648             return self.spines['top'].get_spine_transform()
#     649         else:
#     650             raise ValueError('unknown value for which')
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/spines.py in get_spine_transform(self)
#     404     def get_spine_transform(self):
#     405         """get the spine transform"""
# --> 406         self._ensure_position_is_set()
#     407         what, how = self._spine_transform
#     408
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/spines.py in _ensure_position_is_set(self)
#     150             # default position
#     151             self._position = ('outward', 0.0)  # in points
# --> 152             self.set_position(self._position)
#     153
#     154     def register_axis(self, axis):
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/spines.py in set_position(self, position)
#     394
#     395         if self.axis is not None:
# --> 396             self.axis.reset_ticks()
#     397         self.stale = True
#     398
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in reset_ticks(self)
#     756         cbook.popall(self.minorTicks)
#     757
# --> 758         self.majorTicks.extend([self._get_tick(major=True)])
#     759         self.minorTicks.extend([self._get_tick(major=False)])
#     760         self._lastNumMajorTicks = 1
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1675         else:
#    1676             tick_kw = self._minor_tick_kw
# -> 1677         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1678
#    1679     def _get_label(self):
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     400                           linestyle='None', marker=self._tickmarkers[0],
#     401                           markersize=self._size,
# --> 402                           markeredgewidth=self._width, zorder=self._zorder)
#     403         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     404         self._set_artist_props(l)
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     351         self._color = None
#     352         self.set_color(color)
# --> 353         self._marker = MarkerStyle()
#     354         self.set_marker(marker)
#     355
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     169         # _recache() in set_marker.
#     170         self._fillstyle = fillstyle
# --> 171         self.set_marker(marker)
#     172         self.set_fillstyle(fillstyle)
#     173
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     253
#     254         self._marker = marker
# --> 255         self._recache()
#     256
#     257     def get_path(self):
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/markers.py in _recache(self)
#     184     def _recache(self):
#     185         self._path = Path(np.empty((0, 2)))
# --> 186         self._transform = IdentityTransform()
#     187         self._alt_path = None
#     188         self._alt_transform = None
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/transforms.py in __init__(self, *args, **kwargs)
#    1639
#    1640     def __init__(self, *args, **kwargs):
# -> 1641         Transform.__init__(self, *args, **kwargs)
#    1642         self._inverted = None
#    1643
#
# /users/payno/.local/lib/python3.5/site-packages/matplotlib/transforms.py in __init__(self, shorthand_name)
#      96         # parents are deleted, references from the children won't keep
#      97         # them alive.
# ---> 98         self._parents = WeakValueDictionary()
#      99
#     100         # TransformNodes start out as invalid until their values are
#
# /usr/local/lib/python3.5/weakref.py in __init__(*args, **kw)
#     118         self._iterating = set()
#     119         self.data = d = {}
# --> 120         self.update(*args, **kw)
#     121
#     122     def _commit_removals(self):
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# # display the pixel intensity distribution

# %% [markdown]
# ## create the histogramnd
# - using silx.math.histogram.Histogramnd
#
# - http://www.silx.org/doc/silx/dev/modules/math/histogram.html

# %%
from silx.math.histogram import Histogramnd
histo, w_histo, edges = Histogramnd(image.flatten(), 
                                    n_bins=256, 
                                    histo_range=[0,256])

# %% [markdown]
# ## plot the histogram
# - using silx.gui.plot.Plot1d

# %%
from silx.gui.plot import Plot1D
plotHisto = Plot1D()
plotHisto.addCurve(range(256), histo, legend='intensity')
plotHisto.show()

# %% [markdown]
# # create a PlotAction which plot the histogram for the current image
#
# - using silx.gui.plot.PlotActions.PlotAction
#
# - doc@ http://www.silx.org/doc/silx/dev/modules/gui/plot/plotactions_examples.html
#
# ![simple-image](../img/plot_image-pixel_intensity.png)

# %%
from silx.gui.plot.PlotActions import PlotAction 
from silx.math.histogram import Histogramnd 
from silx.gui.plot import Plot1D

class ComputeHistogramAction(PlotAction):
    """Computes the intensity distribution on the current image

    :param plot: :class:`.PlotWidget` instance on which to operate
    :param parent: See :class:`QAction`
    """
    -

# %% [markdown]
# ## Add this action into the toolBar of the window

# %%
plotHisto.clear()
myaction=ComputeHistogramAction(plotImage)
toolBar=plotImage.toolBar()
toolBar.addAction(myaction)
plotImage.show()

# %% [markdown]
# # show automatically the histogram when the image change
#
# - using plotImage.sigActiveImageChanged.connect(plotHisto)

# %%
from silx.math.histogram import Histogramnd 

def computeIntensityDistribution():
        """Get the active image and compute the image 
        intensity distribution"""
        # By inheriting from PlotAction, we get access to attribute 
        # self.plot
        # which is a reference to the PlotWindow
        activeImage = plotImage.getActiveImage()

        if activeImage is not None:
            histo, w_histo, edges = Histogramnd(activeImage[0].flatten(), 
                                                n_bins=256, 
                                                histo_range=[0,256])
            
            from silx.gui.plot import Plot1D
            plotHistogram = Plot1D()
            plotHistogram.addCurve(range(256), 
                                   histo, 
                                   legend='pixel intensity')
            plotHistogram.show()

# %%
plotImage=Plot2D()
plotImage.sigActiveImageChanged.connect(computeIntensityDistribution)
plotImage.addImage(image, origin=(0, 0), legend='lena')

# %%
from silx.gui.plot.PlotActions import PlotAction 
from silx.math.histogram import Histogramnd
from silx.gui.plot import Plot1D

class ComputeHistogramAction(PlotAction):
    """Computes the intensity distribution on the current image

    :param plot: :class:`.PlotWidget` instance on which to operate
    :param parent: See :class:`QAction`
    """
    def __init__(self, plot, parent=None):
        PlotAction.__init__(self,
                            plot,
                            icon='shape-circle',
                            text='pixels intensity',
                            tooltip='Compute image intensity distribution',
                            triggered=self.computeIntensityDistribution,
                            checkable=True,
                            parent=parent)
        self.plotHistogram=Plot1D()
        self.plot.sigActiveImageChanged.connect(self.update)
        
    def update(self):
        # By inheriting from PlotAction, we get access to attribute 
        # self.plot
        # which is a reference to the PlotWindow
        activeImage = self.plot.getActiveImage()

        if activeImage is not None:
            
            histo, w_histo, edges = Histogramnd(activeImage[0].flatten(), 
                                                          n_bins=256, 
                                                          histo_range=[0,256])
            
            self.plotHistogram.addCurve(range(256), 
                                        histo, 
                                        legend='pixel intensity')
            
    def computeIntensityDistribution(self):
        """Get the active image and compute the image intensity distribution"""
        if self.isChecked():
            self.update()
            self.plotHistogram.show()
        else:
            self.plotHistogram.hide()

# %%
plotImage=Plot2D()
myaction=ComputeHistogramAction(plotImage)
toolBar=plotImage.toolBar()
toolBar.addAction(myaction)
plotImage.addImage(image, origin=(0, 0), legend='lena')  
plotImage.show()

# %%
plotImage.addImage(image/2.0, origin=(0, 0), legend='lena')

# %% [markdown]
# # For information : the class diagram of the Plot module

# %% [markdown]
# ![plot class diagram](../img/plotGraph.png)
